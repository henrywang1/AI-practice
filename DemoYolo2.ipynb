# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/henrywang1/AI-practice/blob/master/DemoYolo2.ipynb)

# %%
# !git clone https://github.com/allanzelener/yad2k.git

# %%
# !wget http://pjreddie.com/media/files/yolo.weights
# !wget https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/yolov2.cfg
# !mkdir images
# !mkdir images/out

# %%
import os
os.chdir('yad2k')

# %%
# !./yad2k.py yolov2.cfg yolo.weights model_data/yolo.h5
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  [       0        1        0 32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2018-05-07 05:59:11.753800: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-05-07 05:59:11.754321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1344] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...

# %%
import test_yolo
args = test_yolo.parser.parse_known_args()[0]
args.model_path = 'model_data/yolo.h5'
test_yolo._main(args)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/models.py:282: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# model_data/yolo.h5 model, anchors, and classes loaded.
# Found 3 boxes for dog.jpg
# truck 0.79 (441, 80) (703, 171)
# dog 0.79 (123, 222) (327, 528)
# bicycle 0.83 (128, 127) (570, 435)
# Found 1 boxes for eagle.jpg
# bird 0.90 (144, 89) (618, 445)
# Found 2 boxes for giraffe.jpg
# zebra 0.80 (290, 199) (430, 451)
# giraffe 0.88 (172, 31) (452, 420)
# Found 3 boxes for person.jpg
# dog 0.82 (61, 264) (200, 351)
# horse 0.86 (404, 133) (602, 344)
# person 0.87 (190, 94) (276, 380)
# Found 0 boxes for scream.jpg
# Found 5 boxes for horses.jpg
# horse 0.42 (98, 176) (463, 349)
# horse 0.69 (237, 201) (426, 370)
# horse 0.71 (0, 197) (153, 384)
# horse 0.83 (436, 211) (603, 348)
# horse 0.90 (0, 191) (335, 414)

# %%
import os
import cv2
from matplotlib import pyplot as plt
files = os.listdir('images/out/')
files = ['images/out/'+ f for f in files]
for f in files:
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    im = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h,w = im.shape[:2]
    print(im.shape)
    plt.grid(False)
    plt.imshow(im)
    plt.show()
# Out:
# (576, 768, 3)
# (512, 773, 3)
# (500, 500, 3)
# (424, 640, 3)
# (448, 352, 3)
# (512, 773, 3)
